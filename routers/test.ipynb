# %%
from ParseVct import Vct
vct = Vct(r'E:\工作文档\(500104)2023年度国土变更调查数据库更新成果\更新数据包\标准格式数据\2001H2023500104GX.vct')
# vct.TableStructure[] = ({'要素代码': '2001010100', '要素名称': 'DSAFSAF', '图形类型': 'Polygon', '属性表名': 'DLTBGX'})
print(vct.TableStructure['DLTBGX'])
print(vct.TableStructure.text)
# Out:
# [<ParseVct.TableStructure.Field object at 0x000001F825E93750>, <ParseVct.TableStructure.Field object at 0x000001F825E93890>, <ParseVct.TableStructure.Field object at 0x000001F825E939D0>, <ParseVct.TableStructure.Field object at 0x000001F825E93AD0>, <ParseVct.TableStructure.Field object at 0x000001F825E93BD0>, <ParseVct.TableStructure.Field object at 0x000001F825E93D50>, <ParseVct.TableStructure.Field object at 0x000001F825E93E50>, <ParseVct.TableStructure.Field object at 0x000001F825E93F90>, <ParseVct.TableStructure.Field object at 0x000001F825E7C110>, <ParseVct.TableStructure.Field object at 0x000001F825E7C210>, <ParseVct.TableStructure.Field object at 0x000001F825E7C350>, <ParseVct.TableStructure.Field object at 0x000001F825E7C490>, <ParseVct.TableStructure.Field object at 0x000001F825E7C590>, <ParseVct.TableStructure.Field object at 0x000001F825E7C690>, <ParseVct.TableStructure.Field object at 0x000001F825E7C7D0>, <ParseVct.TableStructure.Field object at 0x000001F825E7C910>, <Pars
# ...

# %%
import pandas as pd
data = pd.read_excel(r"E:\工作文档\测试导出数据\飞出情况跑表格式.xlsx")
df = data[data.QLRMC2.str.contains("(河流)|(已征地)",regex=True)]
df
